# %% [markdown]
# # WebMD Drug Reviews Data Analysis
#
# Hayley Caddes

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from scipy import stats
import plotly.plotly as py
import plotly.graph_objs as go
import plotly.figure_factory as ff
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
# %matplotlib inline

# %%
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
drugs = pd.read_csv('webmd_Final.csv')

# %%
drugs.head()
# Out:
#              drug        date  \
# 0  methadone oral   5/16/2018
# 1  methadone oral   4/10/2018
# 2  methadone oral  11/16/2017
# 3  methadone oral   8/31/2017
# 4  methadone oral    6/7/2017
#
#                                            condition    age gender  \
# 0                    Prevention of Opiate Drug Abuse  45-54    NaN
# 1                                               Pain  25-34   Male
# 2                                       Chronic Pain  55-64    NaN
# 3  Symptoms from Stopping Treatment with Opioid D...  65-74   Male
# 4                                       Chronic Pain  25-34    NaN
#
#                treatment_length reviewer_status  effectiveness  ease_of_use  \
# 0  6 months to less than 1 year         Patient              5            5
# 1                 1 to 6 months       Caregiver              3            4
# 2       5 to less than 10 years         Patient              5            5
# 3              10 years or more         Patient              2            5
# 4              10 years or more         Patient              5            5
#
#    satisfaction                                            comment
# 0             5  I have been taking 70 mg of methadone for 2 mo...
# 1             5  Online shop where you get 100% authentic produ...
# 2             5  I have Fibromyalgia, and after going to severa...
# 3             2  I've been taking pain meds for 40 years due to...
# 4             5  I don't understand why other physicians say th...

# %%
drugs.date = pd.to_datetime(drugs.date)

# %%
print(drugs.shape)
drugs.head()
# Out:
# (8448, 11)
#              drug       date  \
# 0  methadone oral 2018-05-16
# 1  methadone oral 2018-04-10
# 2  methadone oral 2017-11-16
# 3  methadone oral 2017-08-31
# 4  methadone oral 2017-06-07
#
#                                            condition    age gender  \
# 0                    Prevention of Opiate Drug Abuse  45-54    NaN
# 1                                               Pain  25-34   Male
# 2                                       Chronic Pain  55-64    NaN
# 3  Symptoms from Stopping Treatment with Opioid D...  65-74   Male
# 4                                       Chronic Pain  25-34    NaN
#
#                treatment_length reviewer_status  effectiveness  ease_of_use  \
# 0  6 months to less than 1 year         Patient              5            5
# 1                 1 to 6 months       Caregiver              3            4
# 2       5 to less than 10 years         Patient              5            5
# 3              10 years or more         Patient              2            5
# 4              10 years or more         Patient              5            5
#
#    satisfaction                                            comment
# 0             5  I have been taking 70 mg of methadone for 2 mo...
# 1             5  Online shop where you get 100% authentic produ...
# 2             5  I have Fibromyalgia, and after going to severa...
# 3             2  I've been taking pain meds for 40 years due to...
# 4             5  I don't understand why other physicians say th...

# %% [markdown]
# ## Business Case for non-opiod pain medications
#
# __Market Research -- Questions that must be answered:__
#
# 1. Who are the customers?
# 2. What are the _expectations_?
# 3. What _market segments_ should be high priority?
# 4. What is the _competitive target_?
# 5. What _messages_ should be used launch the product?
# 6. What is the _ideal positioning_ for a new brand to ensure the greatest long-term commercial opportunity?

# %% [markdown]
# ### Who are the customers?
#
# #### What is the distribution of genders for each drugs' users?

# %%
# Filter reviews from caregivers out of the dataframe
patients = drugs.loc[(drugs.reviewer_status != 'Caregiver'),:]
print(patients.shape)

# group by drug & patient sex
group1 = patients.groupby(['drug', 'gender'], as_index=False)
# new dataframe with drug, gender, and total count of each category
data1 = patients.groupby(['drug', 'gender']).agg({'gender': 'count'}).rename(columns={'gender': 'total'}).reset_index()
data1
# Out:
# (8219, 11)
#               drug  gender  total
# 0    Opana ER oral  Female    277
# 1    Opana ER oral    Male    187
# 2   OxyContin oral  Female    630
# 3   OxyContin oral    Male    643
# 4   methadone oral  Female    580
# 5   methadone oral    Male    430
# 6    morphine oral  Female    212
# 7    morphine oral    Male    210
# 8   oxycodone oral  Female    881
# 9   oxycodone oral    Male    814
# 10   tramadol oral  Female   1796
# 11   tramadol oral    Male    818

# %%
# Color scales
import colorlover as cl
from IPython.display import HTML

# %%
HTML(cl.to_html(cl.scales['9']))
# Out:
# <h4>Diverging</h4><div style="display:inline-block;padding:10px;"><div>BrBG</div><div style="background-color:rgb(140,81,10);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(191,129,45);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(223,194,125);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(246,232,195);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(245,245,245);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(199,234,229);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(128,205,193);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(53,151,143);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(1,102,94);height:20px;width:20px;display:inline-block;"></div></div><div style="display:inline-block;padding:10px;"><div>PRGn</div><div style="background-color:rgb(118,42,131);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(153,112,171);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(194,165,207);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(231,212,232);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(247,247,247);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(217,240,211);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(166,219,160);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(90,174,97);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(27,120,55);height:20px;width:20px;display:inline-block;"></div></div><div style="display:inline-block;padding:10px;"><div>PiYG</div><div style="background-color:rgb(197,27,125);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(222,119,174);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(241,182,218);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(253,224,239);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(247,247,247);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(230,245,208);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(184,225,134);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(127,188,65);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(77,146,33);height:20px;width:20px;display:inline-block;"></div></div><div style="display:inline-block;padding:10px;"><div>PuOr</div><div style="background-color:rgb(179,88,6);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(224,130,20);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(253,184,99);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(254,224,182);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(247,247,247);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(216,218,235);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(178,171,210);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(128,115,172);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(84,39,136);height:20px;width:20px;display:inline-block;"></div></div><div style="display:inline-block;padding:10px;"><div>RdBu</div><div style="background-color:rgb(178,24,43);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(214,96,77 ...

# %%
colorM = cl.scales['4']['div']['BrBG'][2]
colorF = cl.scales['10']['div']['PRGn'][1]

# %%
# Interactive plotly graph to see drug consumers by gender

drugNames = data1.drug.unique()

trace1 = go.Bar(x = drugNames, 
                y = data1.total[data1.gender == 'Male'] , 
                name = 'Male',
                marker = dict(color = colorM))
trace2 = go.Bar(x = drugNames, 
                y = data1.total[data1.gender == 'Female'] , 
                name = 'Female',
                marker = dict(color = colorF))

layout = go.Layout(title = 'Gender by Drug')
data = [trace1, trace2]
iplot(go.Figure(data = data, layout = layout))
# Out:
# <div id="f394dd57-5555-4186-b2cd-cbddd4979d73" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             'f394dd57-5555-4186-b2cd-cbddd4979d73',
#             [{"marker": {"color": "rgb(128,205,193)"}, "name": "Male", "x": ["Opana ER oral", "OxyContin oral", "methadone oral", "morphine oral", "oxycodone oral", "tramadol oral"], "y": [187.0, 643.0, 430.0, 210.0, 814.0, 818.0], "type": "bar", "uid": "19121cdc-9ab2-11e8-b0b5-c49ded1fd344"}, {"marker": {"color": "rgb(118,42,131)"}, "name": "Female", "x": ["Opana ER oral", "OxyContin oral", "methadone oral", "morphine oral", "oxycodone oral", "tramadol oral"], "y": [277.0, 630.0, 580.0, 212.0, 881.0, 1796.0], "type": "bar", "uid": "19121cdd-9ab2-11e8-862f-c49ded1fd344"}],
#             {"title": "Gender by Drug"},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('f394dd57-5555-4186-b2cd-cbddd4979d73',{});}).then(function(){Plotly.animate('f394dd57-5555-4186-b2cd-cbddd4979d73');})
#         });</script>

# %% [markdown]
# #### Which age groups are the move prevalent patients?

# %%
# group by drug and age group
data2 = patients.groupby(['drug', 'age']).agg({'age': 'count'}).rename(columns={'age': 'total'}).reset_index()
data2.head(8)
# Out:
#              drug         age  total
# 0   Opana ER oral       19-24     10
# 1   Opana ER oral       25-34     52
# 2   Opana ER oral       35-44    106
# 3   Opana ER oral       45-54    183
# 4   Opana ER oral       55-64     99
# 5   Opana ER oral       65-74     22
# 6   Opana ER oral  75 or over      3
# 7  OxyContin oral       13-18      4

# %%
# interactive plot of age distribution
ages = sorted(data2.age.unique())

col = []
for i in range(0, len(ages)):
    col.append(cl.scales['9']['seq']['BuPu'][i+1])


trace = []
for i in range(0, len(ages)):
    trace.append(go.Bar(x = drugNames,
                        y = data2.total[data2.age == ages[i]], 
                        name = ages[i],
                        marker = dict(color = col[i])
                        ))
layout = go.Layout(title = 'Age Groups by Drug')
    
iplot(go.Figure(data = trace, layout = layout))
# Out:
# <div id="bff75a5e-cdf1-422a-9d16-ad017616a775" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             'bff75a5e-cdf1-422a-9d16-ad017616a775',
#             [{"marker": {"color": "rgb(224,236,244)"}, "name": "13-18", "x": ["Opana ER oral", "OxyContin oral", "methadone oral", "morphine oral", "oxycodone oral", "tramadol oral"], "y": [4.0, 1.0, 3.0, 8.0, 13.0], "type": "bar", "uid": "3127bb52-9ab2-11e8-b0a4-c49ded1fd344"}, {"marker": {"color": "rgb(191,211,230)"}, "name": "19-24", "x": ["Opana ER oral", "OxyContin oral", "methadone oral", "morphine oral", "oxycodone oral", "tramadol oral"], "y": [10.0, 45.0, 37.0, 9.0, 81.0, 136.0], "type": "bar", "uid": "3127bb53-9ab2-11e8-bf00-c49ded1fd344"}, {"marker": {"color": "rgb(158,188,218)"}, "name": "25-34", "x": ["Opana ER oral", "OxyContin oral", "methadone oral", "morphine oral", "oxycodone oral", "tramadol oral"], "y": [52.0, 145.0, 206.0, 46.0, 215.0, 373.0], "type": "bar", "uid": "3127bb54-9ab2-11e8-95e7-c49ded1fd344"}, {"marker": {"color": "rgb(140,150,198)"}, "name": "35-44", "x": ["Opana ER oral", "OxyContin oral", "methadone oral", "morphine oral", "oxycodone oral", "tramadol oral"], "y": [106.0, 280.0, 229.0, 71.0, 352.0, 452.0], "type": "bar", "uid": "3127bb55-9ab2-11e8-b601-c49ded1fd344"}, {"marker": {"color": "rgb(140,107,177)"}, "name": "45-54", "x": ["Opana ER oral", "OxyContin oral", "methadone oral", "morphine oral", "oxycodone oral", "tramadol oral"], "y": [183.0, 451.0, 327.0, 144.0, 510.0, 695.0], "type": "bar", "uid": "3127bb56-9ab2-11e8-9ef5-c49ded1fd344"}, {"marker": {"color": "rgb(136,65,157)"}, "name": "55-64", "x": ["Opana ER oral", "OxyContin oral", "methadone oral", "morphine oral", "oxycodone oral", "tramadol oral"], "y": [99.0, 271.0, 176.0, 125.0, 405.0, 600.0], "type": "bar", "uid": "3127bb57-9ab2-11e8-8035-c49ded1fd344"}, {"marker": {"color": "rgb(129,15,124)"}, "name": "65-74", "x": ["Opana ER oral", "OxyContin oral", "methadone oral", "morphine oral", "oxycodone oral", "tramadol oral"], "y": [22.0, 81.0, 36.0, 34.0, 123.0, 298.0], "type": "bar", "uid": "3127bb58-9ab2-11e8-8366-c49ded1fd344"}, {"marker": {"color": "rgb(77,0,75)"}, "name": "75 or over", "x": ["Opana ER oral", "OxyContin oral", "methadone oral", "morphine oral", "oxycodone oral", "tramadol oral"], "y": [3.0, 14.0, 5.0, 13.0, 34.0, 101.0], "type": "bar", "uid": "3127bb59-9ab2-11e8-9040-c49ded1fd344"}],
#             {"title": "Age Groups by Drug"},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('bff75a5e-cdf1-422a-9d16-ad017616a775',{});}).then(function(){Plotly.animate('bff75a5e-cdf1-422a-9d16-ad017616a775');})
#         });</script>

# %% [markdown]
# #### For how long do patients use these drugs?

# %%
# How long do patients typically use these drugs?

# group by drug and treatment length
data3 = patients.groupby(['drug', 'treatment_length']).agg({'treatment_length': 'count'}).rename(columns={'treatment_length': 'total'}).reset_index()
data3.head(7)
# Out:
#             drug              treatment_length  total
# 0  Opana ER oral                 1 to 6 months    130
# 1  Opana ER oral        1 to less than 2 years     73
# 2  Opana ER oral              10 years or more      6
# 3  Opana ER oral        2 to less than 5 years     59
# 4  Opana ER oral       5 to less than 10 years     14
# 5  Opana ER oral  6 months to less than 1 year     56
# 6  Opana ER oral             less than 1 month    127

# %%
# interactive plot of treatment length
sortedLength = ['less than 1 month', '1 to 6 months', '6 months to less than 1 year', '1 to less than 2 years', '2 to less than 5 years', '5 to less than 10 years', '10 years or more']
col = []
for i in range(1, len(sortedLength)+1):
    col.append(cl.scales['9']['seq']['BuGn'][i+1])
    
trace = []
for i in range(0, len(sortedLength)):
    trace.append(go.Bar(x = drugNames,
                        y = data3.total[data3.treatment_length == sortedLength[i]], 
                        name = sortedLength[i],
                        marker = dict(color=col[i])
                        ))
layout = go.Layout(title = 'Treatment Length by Drug')
    
iplot(go.Figure(data = trace, layout = layout))
# Out:
# <div id="96cac902-1db8-4b58-ab10-613d3ad54e95" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '96cac902-1db8-4b58-ab10-613d3ad54e95',
#             [{"marker": {"color": "rgb(204,236,230)"}, "name": "less than 1 month", "x": ["Opana ER oral", "OxyContin oral", "methadone oral", "morphine oral", "oxycodone oral", "tramadol oral"], "y": [127.0, 145.0, 121.0, 106.0, 310.0, 773.0], "type": "bar", "uid": "3403dffa-9ab2-11e8-995d-c49ded1fd344"}, {"marker": {"color": "rgb(153,216,201)"}, "name": "1 to 6 months", "x": ["Opana ER oral", "OxyContin oral", "methadone oral", "morphine oral", "oxycodone oral", "tramadol oral"], "y": [130.0, 153.0, 120.0, 78.0, 297.0, 614.0], "type": "bar", "uid": "3403dffb-9ab2-11e8-85bc-c49ded1fd344"}, {"marker": {"color": "rgb(102,194,164)"}, "name": "6 months to less than 1 year", "x": ["Opana ER oral", "OxyContin oral", "methadone oral", "morphine oral", "oxycodone oral", "tramadol oral"], "y": [56.0, 114.0, 86.0, 41.0, 153.0, 304.0], "type": "bar", "uid": "3403dffc-9ab2-11e8-9ac3-c49ded1fd344"}, {"marker": {"color": "rgb(65,174,118)"}, "name": "1 to less than 2 years", "x": ["Opana ER oral", "OxyContin oral", "methadone oral", "morphine oral", "oxycodone oral", "tramadol oral"], "y": [73.0, 165.0, 165.0, 35.0, 223.0, 287.0], "type": "bar", "uid": "3403dffd-9ab2-11e8-b7c8-c49ded1fd344"}, {"marker": {"color": "rgb(35,139,69)"}, "name": "2 to less than 5 years", "x": ["Opana ER oral", "OxyContin oral", "methadone oral", "morphine oral", "oxycodone oral", "tramadol oral"], "y": [59.0, 305.0, 240.0, 65.0, 380.0, 401.0], "type": "bar", "uid": "3403dffe-9ab2-11e8-a399-c49ded1fd344"}, {"marker": {"color": "rgb(0,109,44)"}, "name": "5 to less than 10 years", "x": ["Opana ER oral", "OxyContin oral", "methadone oral", "morphine oral", "oxycodone oral", "tramadol oral"], "y": [14.0, 242.0, 166.0, 63.0, 216.0, 188.0], "type": "bar", "uid": "3403dfff-9ab2-11e8-b77f-c49ded1fd344"}, {"marker": {"color": "rgb(0,68,27)"}, "name": "10 years or more", "x": ["Opana ER oral", "OxyContin oral", "methadone oral", "morphine oral", "oxycodone oral", "tramadol oral"], "y": [6.0, 137.0, 111.0, 40.0, 109.0, 68.0], "type": "bar", "uid": "3403e000-9ab2-11e8-b983-c49ded1fd344"}],
#             {"title": "Treatment Length by Drug"},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('96cac902-1db8-4b58-ab10-613d3ad54e95',{});}).then(function(){Plotly.animate('96cac902-1db8-4b58-ab10-613d3ad54e95');})
#         });</script>

# %% [markdown]
# ### What is the competitive target?
#
# #### What is the distribution of the different conditions treated by all the pain medications in the dataset?

# %%
# Let's look at the different conditions
data4 = patients.groupby(['condition']).agg({'condition': 'count'}).rename(columns={'condition': 'total'}).reset_index()
data4
# Out:
#                                             condition  total
# 0                   Acute Pain Following an Operation     16
# 1       Additional Agent to Induce General Anesthesia      2
# 2                         Additional Local Anesthesia      1
# 3   Calming of Intubated Patient by Administration...      2
# 4                                        Chronic Pain   1489
# 5           Chronic Pain with Narcotic Drug Tolerance    437
# 6                                               Cough      1
# 7   Disorder characterized by Stiff, Tender & Pain...    332
# 8          Drug Withdrawal Syndrome in Newborn Infant      3
# 9                                  Fluid in the Lungs      2
# 10     Joint Damage causing Pain and Loss of Function     71
# 11                                 Narcotic Addiction    199
# 12                                   Neuropathic Pain    809
# 13                                              Other    337
# 14                                               Pain   4124
# 15                    Prevention of Opiate Drug Abuse     83
# 16                                        Severe Pain    210
# 17                  Severe Pain with Opioid Tolerance     84
# 18  Symptoms from Stopping Treatment with Opioid D...     16

# %%
conditions = patients.condition.drop_duplicates().reset_index(drop=True)
conditions
# Out:
# 0                       Prevention of Opiate Drug Abuse
# 1                                          Chronic Pain
# 2     Symptoms from Stopping Treatment with Opioid D...
# 3                                                  Pain
# 4                                           Severe Pain
# 5                                    Narcotic Addiction
# 6                                                 Other
# 7                                                   NaN
# 8                                                 Cough
# 9            Drug Withdrawal Syndrome in Newborn Infant
# 10            Chronic Pain with Narcotic Drug Tolerance
# 11                    Severe Pain with Opioid Tolerance
# 12        Additional Agent to Induce General Anesthesia
# 13    Calming of Intubated Patient by Administration...
# 14                                   Fluid in the Lungs
# 15                          Additional Local Anesthesia
# 16                    Acute Pain Following an Operation
# 17                                     Neuropathic Pain
# 18       Joint Damage causing Pain and Loss of Function
# 19    Disorder characterized by Stiff, Tender & Pain...
# Name: condition, dtype: object

# %%
# combine some conditions into groups
cg = {}
# Pain
cg['Acute Pain'] = [conditions[3], conditions[16]] 
# Chronic Pain
cg['Chronic Pain'] = [conditions[1], conditions[18]] 
# Neuropathic Pain
cg['Neuropathic Pain'] = [conditions[17]]
# Pain with drug tolerance
cg['Pain with Drug Tolerance'] = [conditions[10], conditions[11]]
# Other
cg['Other'] = [conditions[6], conditions[7], conditions[14]]
# Addiction/Drug abuse
cg['Drug Abuse'] = [conditions[5], conditions[0], conditions[2], conditions[9]]
# Severe pain
cg['Severe Pain'] = [conditions[4]]
# Muscle Pain
cg['Stiff, Tender, & Painful Muscles'] = [conditions[19]]
# Anesthesia
cg['Anesthesia'] = [conditions[12], conditions[13], conditions[15]]

# %%
# let's eliminate any of the conditions with less than 10 observations
# let's also look at the proportion of condition over the total (condition is a required field in writing a webmd drug review)
totPat = patients.shape[0]


data5 = data4[(data4.total >= 10)].sort_values('total', ascending=False).reset_index(drop=True)
print(data4.total.sum())
data5.total = data5.total.apply(lambda x: x/totPat)
data5
# Out:
# 8218
#                                             condition     total
# 0                                                Pain  0.501764
# 1                                        Chronic Pain  0.181166
# 2                                    Neuropathic Pain  0.098430
# 3           Chronic Pain with Narcotic Drug Tolerance  0.053169
# 4                                               Other  0.041003
# 5   Disorder characterized by Stiff, Tender & Pain...  0.040394
# 6                                         Severe Pain  0.025551
# 7                                  Narcotic Addiction  0.024212
# 8                   Severe Pain with Opioid Tolerance  0.010220
# 9                     Prevention of Opiate Drug Abuse  0.010099
# 10     Joint Damage causing Pain and Loss of Function  0.008639
# 11                  Acute Pain Following an Operation  0.001947
# 12  Symptoms from Stopping Treatment with Opioid D...  0.001947

# %%
# add a 'group' column to data5
data5['group'] = data5['condition'].apply(lambda x: [key for key in cg.keys() for value in cg[key] if x == value][0])
data5
# Out:
#                                             condition     total  \
# 0                                                Pain  0.501764
# 1                                        Chronic Pain  0.181166
# 2                                    Neuropathic Pain  0.098430
# 3           Chronic Pain with Narcotic Drug Tolerance  0.053169
# 4                                               Other  0.041003
# 5   Disorder characterized by Stiff, Tender & Pain...  0.040394
# 6                                         Severe Pain  0.025551
# 7                                  Narcotic Addiction  0.024212
# 8                   Severe Pain with Opioid Tolerance  0.010220
# 9                     Prevention of Opiate Drug Abuse  0.010099
# 10     Joint Damage causing Pain and Loss of Function  0.008639
# 11                  Acute Pain Following an Operation  0.001947
# 12  Symptoms from Stopping Treatment with Opioid D...  0.001947
#
#                                group
# 0                         Acute Pain
# 1                       Chronic Pain
# 2                   Neuropathic Pain
# 3           Pain with Drug Tolerance
# 4                              Other
# 5   Stiff, Tender, & Painful Muscles
# 6                        Severe Pain
# 7                         Drug Abuse
# 8           Pain with Drug Tolerance
# 9                         Drug Abuse
# 10                      Chronic Pain
# 11                        Acute Pain
# 12                        Drug Abuse

# %%
# lets clean up the drugs dataset so we can add a group column to the whole dataframe
drugs2 = drugs[(drugs.condition.isin([x for values in cg.values() for x in values]))].reset_index(drop = True)
drugs2.replace("NaN", np.nan, inplace = True)
print(drugs2.shape)
patients = drugs2.loc[(drugs2.reviewer_status != 'Caregiver'),:].reset_index(drop = True)
patients = patients.dropna(subset=['condition'])
print(patients.shape)
# Out:
# (8447, 11)
# (8217, 11)

# %%
# let's also add group column to entire dataframe for easy grouping later
patients['group'] = patients['condition'].apply(lambda x: [key for key in cg.keys() for value in cg[key] if x == value][0])
patients.head()
# Out:
#              drug       date  \
# 0  methadone oral 2018-05-16
# 1  methadone oral 2017-11-16
# 2  methadone oral 2017-08-31
# 3  methadone oral 2017-06-07
# 4  methadone oral 2017-02-19
#
#                                            condition    age  gender  \
# 0                    Prevention of Opiate Drug Abuse  45-54     NaN
# 1                                       Chronic Pain  55-64     NaN
# 2  Symptoms from Stopping Treatment with Opioid D...  65-74    Male
# 3                                       Chronic Pain  25-34     NaN
# 4                                       Chronic Pain  35-44  Female
#
#                treatment_length reviewer_status  effectiveness  ease_of_use  \
# 0  6 months to less than 1 year         Patient              5            5
# 1       5 to less than 10 years         Patient              5            5
# 2              10 years or more         Patient              2            5
# 3              10 years or more         Patient              5            5
# 4        2 to less than 5 years         Patient              5            5
#
#    satisfaction                                            comment  \
# 0             5  I have been taking 70 mg of methadone for 2 mo...
# 1             5  I have Fibromyalgia, and after going to severa...
# 2             2  I've been taking pain meds for 40 years due to...
# 3             5  I don't understand why other physicians say th...
# 4             5  I have had much pain relief from using methado...
#
#           group
# 0    Drug Abuse
# 1  Chronic Pain
# 2    Drug Abuse
# 3  Chronic Pain
# 4  Chronic Pain

# %%
specCol = cl.scales['9']['seq']['GnBu']
specCol40 = cl.to_rgb(cl.interp(specCol, 40))
HTML(cl.to_html(specCol40))
# Out:
# <div style="background-color:rgb(246, 252, 238);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(242, 250, 233);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(237, 248, 229);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(232, 246, 224);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(227, 244, 220);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(222, 242, 216);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(218, 240, 212);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(214, 239, 207);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(210, 237, 202);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(206, 235, 198);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(200, 233, 193);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(191, 230, 187);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(182, 228, 182);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(176, 225, 181);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(171, 222, 180);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(164, 219, 180);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(155, 215, 180);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(146, 212, 183);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(137, 209, 187);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(127, 205, 192);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(118, 204, 196);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(109, 205, 197);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(99, 206, 198);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(89, 208, 200);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(79, 209, 202);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(69, 209, 207);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(59, 203, 208);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(49, 193, 206);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(46, 177, 198);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(43, 162, 189);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(36, 151, 185);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(28, 142, 183);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(21, 131, 179);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(15, 121, 176);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(9, 110, 171);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(8, 100, 162);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(8, 91, 153);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(8, 82, 143);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(8, 74, 134);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(8, 66, 125);height:20px;width:20px;display:inline-block;"></div>

# %%
data6 = data5.groupby('group').agg({'total': 'sum'}).sort_values('total').reset_index()
data6
# Out:
#                               group     total
# 0                       Severe Pain  0.025551
# 1                        Drug Abuse  0.036257
# 2  Stiff, Tender, & Painful Muscles  0.040394
# 3                             Other  0.041003
# 4          Pain with Drug Tolerance  0.063390
# 5                  Neuropathic Pain  0.098430
# 6                      Chronic Pain  0.189804
# 7                        Acute Pain  0.503711

# %%
# interactive plot
groups = data6.group.unique()

col = []
for i in range(1, len(data6)+1):
    col.append(specCol40[i*3])
    
trace = [go.Bar(x = list(data6.group), y = list(data6.total), 
               marker = dict(color = col))]
layout = go.Layout(title = 'Proportion of Conditions Treated', 
                   yaxis = dict(title = 'Proportion'))
    
iplot(go.Figure(data = trace, layout = layout))
# Out:
# <div id="36a65359-2359-47ee-bede-a227e8f0c0d2" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '36a65359-2359-47ee-bede-a227e8f0c0d2',
#             [{"marker": {"color": ["rgb(232, 246, 224)", "rgb(218, 240, 212)", "rgb(206, 235, 198)", "rgb(182, 228, 182)", "rgb(164, 219, 180)", "rgb(137, 209, 187)", "rgb(109, 205, 197)", "rgb(79, 209, 202)"]}, "x": ["Severe Pain", "Drug Abuse", "Stiff, Tender, & Painful Muscles", "Other", "Pain with Drug Tolerance", "Neuropathic Pain", "Chronic Pain", "Acute Pain"], "y": [0.025550553595327898, 0.036257452244798635, 0.040394208541185056, 0.04100255505535953, 0.06338970677698016, 0.09843046599342986, 0.18980411242243583, 0.5037109137364643], "type": "bar", "uid": "3430c4ac-9ab2-11e8-b4d0-c49ded1fd344"}],
#             {"title": "Proportion of Conditions Treated", "yaxis": {"title": "Proportion"}},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('36a65359-2359-47ee-bede-a227e8f0c0d2',{});}).then(function(){Plotly.animate('36a65359-2359-47ee-bede-a227e8f0c0d2');})
#         });</script>

# %% [markdown]
# #### What is the distribution of conditions treated by drug?

# %%
# group by drug and condition group
data7 = patients.groupby(['drug', 'group']).agg({'group': 'count'}).rename(columns={'group': 'total_group'}).reset_index()
data7['total_drug'] = data7['drug'].apply(lambda x: sum(data7.total_group[data7.drug == x]))
data7['prop'] = data7['total_group']/data7['total_drug']
data7 = data7[data7.prop >= 0.01]
data7
# Out:
#               drug                             group  total_group  total_drug  \
# 0    Opana ER oral                        Acute Pain           36         509
# 1    Opana ER oral                      Chronic Pain          251         509
# 2    Opana ER oral                             Other           11         509
# 3    Opana ER oral          Pain with Drug Tolerance          134         509
# 4    Opana ER oral                       Severe Pain           77         509
# 5   OxyContin oral                        Acute Pain           75        1402
# 6   OxyContin oral                      Chronic Pain          885        1402
# 7   OxyContin oral                  Neuropathic Pain           95        1402
# 8   OxyContin oral                             Other           40        1402
# 9   OxyContin oral          Pain with Drug Tolerance          303        1402
# 11  methadone oral                        Acute Pain          631        1091
# 12  methadone oral                      Chronic Pain           29        1091
# 13  methadone oral                        Drug Abuse          301        1091
# 14  methadone oral                             Other           38        1091
# 15  methadone oral                       Severe Pain           92        1091
# 16   morphine oral                        Acute Pain          342         482
# 17   morphine oral                        Anesthesia            5         482
# 19   morphine oral                             Other           13         482
# 20   morphine oral          Pain with Drug Tolerance           84         482
# 21   morphine oral                       Severe Pain           37         482
# 22  oxycodone oral                        Acute Pain         1405        1883
# 23  oxycodone oral                  Neuropathic Pain          395        1883
# 24  oxycodone oral                             Other           83        1883
# 25   tramadol oral                        Acute Pain         1651        2850
# 26   tramadol oral                      Chronic Pain          394        2850
# 27   tramadol oral                  Neuropathic Pain          319        2850
# 28   tramadol oral                             Other          154        2850
# 29   tramadol oral  Stiff, Tender, & Painful Muscles          332        2850
#
#         prop
# 0   0.070727
# 1   0.493124
# 2   0.021611
# 3   0.263261
# 4   0.151277
# 5   0.053495
# 6   0.631241
# 7   0.067760
# 8   0.028531
# 9   0.216120
# 11  0.578368
# 12  0.026581
# 13  0.275894
# 14  0.034830
# 15  0.084326
# 16  0.709544
# 17  0.010373
# 19  0.026971
# 20  0.174274
# 21  0.076763
# 22  0.746150
# 23  0.209772
# 24  0.044079
# 25  0.579298
# 26  0.138246
# 27  0.111930
# 28  0.054035
# 29  0.116491

# %%
# define function to return 0 if a drug doesn't have a certain group

def groupExist(group):
    props = []
    for name in drugNames:
        if group not in list(data7.group[data7.drug == name]):
            props.append(0)
        else:
            props.append(data7.prop[data7[(data7.group == group) & (data7.drug == name)].index.astype(int)[0]])
    return props
        #for group in groups:
            #if group == condition:
                #print(data7.)
        
y = groupExist("Neuropathic Pain")
y
# Out:
# [0, 0.06776034236804565, 0, 0, 0.2097716409984068, 0.1119298245614035]

# %%
col = {}
col['Severe Pain'] = cl.scales['9']['seq']['GnBu'][8]
col['Stiff, Tender, & Painful Muscles'] = cl.scales['9']['seq']['GnBu'][6]
col['Other'] = cl.scales['9']['seq']['GnBu'][5]
col['Anesthesia'] = cl.scales['9']['seq']['GnBu'][1]
col['Neuropathic Pain'] = cl.scales['9']['seq']['GnBu'][3]
col['Pain with Drug Tolerance'] = cl.scales['9']['seq']['GnBu'][2]
col['Chronic Pain'] = cl.scales['9']['seq']['GnBu'][4]
col['Acute Pain'] = cl.scales['9']['seq']['GnBu'][7]
col['Drug Abuse'] = cl.scales['9']['seq']['Greens'][4]

HTML(cl.to_html(list(col.values())))
# Out:
# <div style="background-color:rgb(8,64,129);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(43,140,190);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(78,179,211);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(224,243,219);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(168,221,181);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(204,235,197);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(123,204,196);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(8,104,172);height:20px;width:20px;display:inline-block;"></div><div style="background-color:rgb(116,196,118);height:20px;width:20px;display:inline-block;"></div>

# %%
groups
# Out:
# array(['Severe Pain', 'Drug Abuse', 'Stiff, Tender, & Painful Muscles',
#        'Other', 'Pain with Drug Tolerance', 'Neuropathic Pain',
#        'Chronic Pain', 'Acute Pain'], dtype=object)

# %%
#interactive plot
groups = data7.group.unique()
drugNames = data7.drug.unique()

#col = []
#for i in range(1, len(groups)+1):
#    col.append(specCol40[i*3])
#col.reverse()
    
trace = []
for i in range(0, len(groups)):
    trace.append(go.Bar(x = drugNames,
                        y = groupExist(groups[i]),
                        name = groups[i],
                        marker = dict(color=col[groups[i]])
                        ))
    
layout = go.Layout(title = 'Proportion of Conditions Treated', 
                   yaxis = dict(title = 'Proportion'))
    
iplot(go.Figure(data = trace, layout = layout))
# Out:
# <div id="481e9505-e941-4904-9e31-cdd9b7f7e2a9" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '481e9505-e941-4904-9e31-cdd9b7f7e2a9',
#             [{"marker": {"color": "rgb(8,104,172)"}, "name": "Acute Pain", "x": ["Opana ER oral", "OxyContin oral", "methadone oral", "morphine oral", "oxycodone oral", "tramadol oral"], "y": [0.07072691552062868, 0.05349500713266762, 0.5783684692942255, 0.7095435684647303, 0.7461497610196495, 0.5792982456140351], "type": "bar", "uid": "345d3482-9ab2-11e8-87e1-c49ded1fd344"}, {"marker": {"color": "rgb(123,204,196)"}, "name": "Chronic Pain", "x": ["Opana ER oral", "OxyContin oral", "methadone oral", "morphine oral", "oxycodone oral", "tramadol oral"], "y": [0.4931237721021611, 0.6312410841654779, 0.026581118240146653, 0, 0, 0.13824561403508773], "type": "bar", "uid": "345d3483-9ab2-11e8-8a4f-c49ded1fd344"}, {"marker": {"color": "rgb(78,179,211)"}, "name": "Other", "x": ["Opana ER oral", "OxyContin oral", "methadone oral", "morphine oral", "oxycodone oral", "tramadol oral"], "y": [0.021611001964636542, 0.028530670470756064, 0.034830430797433545, 0.026970954356846474, 0.044078597981943704, 0.05403508771929825], "type": "bar", "uid": "345d3484-9ab2-11e8-bcfb-c49ded1fd344"}, {"marker": {"color": "rgb(204,235,197)"}, "name": "Pain with Drug Tolerance", "x": ["Opana ER oral", "OxyContin oral", "methadone oral", "morphine oral", "oxycodone oral", "tramadol oral"], "y": [0.2632612966601179, 0.2161198288159772, 0, 0.17427385892116182, 0, 0], "type": "bar", "uid": "345d3485-9ab2-11e8-bae0-c49ded1fd344"}, {"marker": {"color": "rgb(8,64,129)"}, "name": "Severe Pain", "x": ["Opana ER oral", "OxyContin oral", "methadone oral", "morphine oral", "oxycodone oral", "tramadol oral"], "y": [0.1512770137524558, 0, 0.0843263061411549, 0.07676348547717843, 0, 0], "type": "bar", "uid": "345d3486-9ab2-11e8-aea6-c49ded1fd344"}, {"marker": {"color": "rgb(168,221,181)"}, "name": "Neuropathic Pain", "x": ["Opana ER oral", "OxyContin oral", "methadone oral", "morphine oral", "oxycodone oral", "tramadol oral"], "y": [0, 0.06776034236804565, 0, 0, 0.2097716409984068, 0.1119298245614035], "type": "bar", "uid": "345d3487-9ab2-11e8-8e58-c49ded1fd344"}, {"marker": {"color": "rgb(116,196,118)"}, "name": "Drug Abuse", "x": ["Opana ER oral", "OxyContin oral", "methadone oral", "morphine oral", "oxycodone oral", "tramadol oral"], "y": [0, 0, 0.2758936755270394, 0, 0, 0], "type": "bar", "uid": "345d3488-9ab2-11e8-9bb8-c49ded1fd344"}, {"marker": {"color": "rgb(224,243,219)"}, "name": "Anesthesia", "x": ["Opana ER oral", "OxyContin oral", "methadone oral", "morphine oral", "oxycodone oral", "tramadol oral"], "y": [0, 0, 0, 0.01037344398340249, 0, 0], "type": "bar", "uid": "345d3489-9ab2-11e8-b42b-c49ded1fd344"}, {"marker": {"color": "rgb(43,140,190)"}, "name": "Stiff, Tender, & Painful Muscles", "x": ["Opana ER oral", "OxyContin oral", "methadone oral", "morphine oral", "oxycodone oral", "tramadol oral"], "y": [0, 0, 0, 0, 0, 0.11649122807017544], "type": "bar", "uid": "345d348a-9ab2-11e8-9993-c49ded1fd344"}],
#             {"title": "Proportion of Conditions Treated", "yaxis": {"title": "Proportion"}},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('481e9505-e941-4904-9e31-cdd9b7f7e2a9',{});}).then(function(){Plotly.animate('481e9505-e941-4904-9e31-cdd9b7f7e2a9');})
#         });</script>

# %% [markdown]
# #### What is the distribution of conditions treated by sex?

# %%
# group by sex and condition group
data8 = patients.groupby(['gender', 'group']).agg({'group': 'count'}).rename(columns={'group': 'total_group'}).reset_index()
data8['total_gender'] = data8['gender'].apply(lambda x: sum(data8.total_group[data8.gender == x]))
data8['prop'] = data8['total_group']/data8['total_gender']
data8 = data8[data8.prop >= 0.01]
data8
# Out:
#     gender                             group  total_group  total_gender  \
# 0   Female                        Acute Pain         2267          4375
# 2   Female                      Chronic Pain          795          4375
# 3   Female                        Drug Abuse          162          4375
# 4   Female                  Neuropathic Pain          388          4375
# 5   Female                             Other          189          4375
# 6   Female          Pain with Drug Tolerance          221          4375
# 7   Female                       Severe Pain          110          4375
# 8   Female  Stiff, Tender, & Painful Muscles          242          4375
# 9     Male                        Acute Pain         1513          3101
# 11    Male                      Chronic Pain          617          3101
# 12    Male                        Drug Abuse          120          3101
# 13    Male                  Neuropathic Pain          325          3101
# 14    Male                             Other          127          3101
# 15    Male          Pain with Drug Tolerance          244          3101
# 16    Male                       Severe Pain           82          3101
# 17    Male  Stiff, Tender, & Painful Muscles           71          3101
#
#         prop
# 0   0.518171
# 2   0.181714
# 3   0.037029
# 4   0.088686
# 5   0.043200
# 6   0.050514
# 7   0.025143
# 8   0.055314
# 9   0.487907
# 11  0.198968
# 12  0.038697
# 13  0.104805
# 14  0.040955
# 15  0.078684
# 16  0.026443
# 17  0.022896

# %%
#interactive plot
groups = data8.group.unique()
    
trace = []
for i in range(0, len(groups)):
    trace.append(go.Bar(x = ["Female", "Male"],
                        y = data8.prop[data8.group == groups[i]],
                        name = groups[i],
                        marker = dict(color=col[groups[i]])
                        ))
    
layout = go.Layout(title = 'Proportion of Conditions Treated', 
                   yaxis = dict(title = 'Proportion'))
    
iplot(go.Figure(data = trace, layout = layout))
# Out:
# <div id="5b238289-8f49-4fa3-8948-f7f1a5cb9664" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '5b238289-8f49-4fa3-8948-f7f1a5cb9664',
#             [{"marker": {"color": "rgb(8,104,172)"}, "name": "Acute Pain", "x": ["Female", "Male"], "y": [0.5181714285714286, 0.4879071267333118], "type": "bar", "uid": "3473468c-9ab2-11e8-8daa-c49ded1fd344"}, {"marker": {"color": "rgb(123,204,196)"}, "name": "Chronic Pain", "x": ["Female", "Male"], "y": [0.18171428571428572, 0.19896807481457596], "type": "bar", "uid": "3473468d-9ab2-11e8-9762-c49ded1fd344"}, {"marker": {"color": "rgb(116,196,118)"}, "name": "Drug Abuse", "x": ["Female", "Male"], "y": [0.03702857142857143, 0.038697194453402126], "type": "bar", "uid": "3473468e-9ab2-11e8-bdd6-c49ded1fd344"}, {"marker": {"color": "rgb(168,221,181)"}, "name": "Neuropathic Pain", "x": ["Female", "Male"], "y": [0.08868571428571428, 0.10480490164463076], "type": "bar", "uid": "3473468f-9ab2-11e8-a7ba-c49ded1fd344"}, {"marker": {"color": "rgb(78,179,211)"}, "name": "Other", "x": ["Female", "Male"], "y": [0.0432, 0.04095453079651725], "type": "bar", "uid": "34734690-9ab2-11e8-a6da-c49ded1fd344"}, {"marker": {"color": "rgb(204,235,197)"}, "name": "Pain with Drug Tolerance", "x": ["Female", "Male"], "y": [0.05051428571428571, 0.07868429538858433], "type": "bar", "uid": "34734691-9ab2-11e8-ac68-c49ded1fd344"}, {"marker": {"color": "rgb(8,64,129)"}, "name": "Severe Pain", "x": ["Female", "Male"], "y": [0.025142857142857144, 0.026443082876491456], "type": "bar", "uid": "34734692-9ab2-11e8-a821-c49ded1fd344"}, {"marker": {"color": "rgb(43,140,190)"}, "name": "Stiff, Tender, & Painful Muscles", "x": ["Female", "Male"], "y": [0.05531428571428571, 0.02289584005159626], "type": "bar", "uid": "34734693-9ab2-11e8-b179-c49ded1fd344"}],
#             {"title": "Proportion of Conditions Treated", "yaxis": {"title": "Proportion"}},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('5b238289-8f49-4fa3-8948-f7f1a5cb9664',{});}).then(function(){Plotly.animate('5b238289-8f49-4fa3-8948-f7f1a5cb9664');})
#         });</script>

# %% [markdown]
# #### What is the distribution of conditions treated by treatment length?

# %%
# group by sex and condition group
data9 = patients.groupby(['treatment_length', 'group']).agg({'group': 'count'}).rename(columns={'group': 'total_group'}).reset_index()
data9['total_length'] = data9['treatment_length'].apply(lambda x: sum(data9.total_group[data9.treatment_length == x]))
data9['prop'] = data9['total_group']/data9['total_length']
data9 = data9[data9.prop >= 0.01]
data9
# Out:
#                 treatment_length                             group  \
# 0                  1 to 6 months                        Acute Pain
# 1                  1 to 6 months                      Chronic Pain
# 2                  1 to 6 months                        Drug Abuse
# 3                  1 to 6 months                  Neuropathic Pain
# 4                  1 to 6 months                             Other
# 5                  1 to 6 months          Pain with Drug Tolerance
# 6                  1 to 6 months                       Severe Pain
# 7                  1 to 6 months  Stiff, Tender, & Painful Muscles
# 8         1 to less than 2 years                        Acute Pain
# 10        1 to less than 2 years                      Chronic Pain
# 11        1 to less than 2 years                        Drug Abuse
# 12        1 to less than 2 years                  Neuropathic Pain
# 13        1 to less than 2 years                             Other
# 14        1 to less than 2 years          Pain with Drug Tolerance
# 15        1 to less than 2 years                       Severe Pain
# 16        1 to less than 2 years  Stiff, Tender, & Painful Muscles
# 17              10 years or more                        Acute Pain
# 18              10 years or more                      Chronic Pain
# 19              10 years or more                        Drug Abuse
# 20              10 years or more                  Neuropathic Pain
# 21              10 years or more                             Other
# 22              10 years or more          Pain with Drug Tolerance
# 23              10 years or more                       Severe Pain
# 24              10 years or more  Stiff, Tender, & Painful Muscles
# 25        2 to less than 5 years                        Acute Pain
# 27        2 to less than 5 years                      Chronic Pain
# 28        2 to less than 5 years                        Drug Abuse
# 29        2 to less than 5 years                  Neuropathic Pain
# 30        2 to less than 5 years                             Other
# 31        2 to less than 5 years          Pain with Drug Tolerance
# 32        2 to less than 5 years                       Severe Pain
# 33        2 to less than 5 years  Stiff, Tender, & Painful Muscles
# 34       5 to less than 10 years                        Acute Pain
# 35       5 to less than 10 years                      Chronic Pain
# 36       5 to less than 10 years                        Drug Abuse
# 37       5 to less than 10 years                  Neuropathic Pain
# 38       5 to less than 10 years                             Other
# 39       5 to less than 10 years          Pain with Drug Tolerance
# 40       5 to less than 10 years                       Severe Pain
# 41       5 to less than 10 years  Stiff, Tender, & Painful Muscles
# 42  6 months to less than 1 year                        Acute Pain
# 43  6 months to less than 1 year                      Chronic Pain
# 44  6 months to less than 1 year                        Drug Abuse
# 45  6 months to less than 1 year                  Neuropathic Pain
# 46  6 months to less than 1 year                             Other
# 47  6 months to less than 1 year          Pain with Drug Tolerance
# 48  6 months to less than 1 year                       Severe Pain
# 49  6 months to less than 1 year  Stiff, Tender, & Painful Muscles
# 50             less than 1 month                        Acute Pain
# 52             less than 1 month                      Chronic Pain
# 53             less than 1 month                        Drug Abuse
# 54             less than 1 month                  Neuropathic Pain
# 55             less than 1 month                             Other
# 56             less than 1 month          Pain with Drug Tolerance
# 57             less than 1 month                       Severe Pain
# 58             less than 1 month  Stiff, Tender, & Painful Muscles
#
#     total_group  total_length      prop
# 0           744          1392  0.534483
# 1           241          1392  0.173132
# 2            35          1392  0.025144
# 3           139          1392  0.099856
# 4            49          1392  0.035201
# 5            76          1392  0.054598
# 6            33          1392  0.023707
# 7            75          1392  0.053879
# 8           477           948  0.503165
# 10          196           948  0.206751
# 11           43           948  0.045359
# 12           91           948  0.095992
# 13           31           948  0.032700
# 14           54           948  0.056962
# 15           26           948  0.027426
# 16           28           948  0.029536
# 17          199           471  0.422505
# 18          106           471  0.225053
# 19           29           471  0.061571
# 20           44           471  0.093418
# 21           14           471  0.029724
# 22           50           471  0.106157
# 23           20           471  0.042463
# 24            9           471  0.019108
# 25          699          1450  0.482069
# 27          297          1450  0.204828
# 28           76          1450  0.052414
# 29          157          1450  0.108276
# 30           45          1450  0.031034
# 31           93          1450  0.064138
# 32           35          1450  0.024138
# 33           47          1450  0.032414
# 34          389           889  0.437570
# 35          220           889  0.247469
# 36           39           889  0.043870
# 37           84           889  0.094488
# 38           34           889  0.038245
# 39           72           889  0.080990
# 40           26           889  0.029246
# 41           25           889  0.028121
# 42          361           754  0.478780
# 43          157           754  0.208223
# 44           33           754  0.043767
# 45           85           754  0.112732
# 46           30           754  0.039788
# 47           43           754  0.057029
# 48           10           754  0.013263
# 49           35           754  0.046419
# 50          911          1580  0.576582
# 52          215          1580  0.136076
# 53           23          1580  0.014557
# 54          124          1580  0.078481
# 55           94          1580  0.059494
# 56           72          1580  0.045570
# 57           46          1580  0.029114
# 58           94          1580  0.059494

# %%
sortedLength
# Out:
# ['less than 1 month',
#  '1 to 6 months',
#  '6 months to less than 1 year',
#  '1 to less than 2 years',
#  '2 to less than 5 years',
#  '5 to less than 10 years',
#  '10 years or more']

# %%
dictLength = {key:value for value, key in enumerate(sortedLength)}
dictLength
# Out:
# {'less than 1 month': 0,
#  '1 to 6 months': 1,
#  '6 months to less than 1 year': 2,
#  '1 to less than 2 years': 3,
#  '2 to less than 5 years': 4,
#  '5 to less than 10 years': 5,
#  '10 years or more': 6}

# %%
# sort the dataframe by treatment_length in custom order sortedLength
data9['treatment_length'] = pd.Categorical(data9['treatment_length'], sortedLength)
data9 = data9.sort_values('treatment_length')
data9
# Out:
#                 treatment_length                             group  \
# 58             less than 1 month  Stiff, Tender, & Painful Muscles
# 56             less than 1 month          Pain with Drug Tolerance
# 55             less than 1 month                             Other
# 54             less than 1 month                  Neuropathic Pain
# 53             less than 1 month                        Drug Abuse
# 52             less than 1 month                      Chronic Pain
# 50             less than 1 month                        Acute Pain
# 57             less than 1 month                       Severe Pain
# 0                  1 to 6 months                        Acute Pain
# 5                  1 to 6 months          Pain with Drug Tolerance
# 7                  1 to 6 months  Stiff, Tender, & Painful Muscles
# 1                  1 to 6 months                      Chronic Pain
# 2                  1 to 6 months                        Drug Abuse
# 3                  1 to 6 months                  Neuropathic Pain
# 4                  1 to 6 months                             Other
# 6                  1 to 6 months                       Severe Pain
# 43  6 months to less than 1 year                      Chronic Pain
# 44  6 months to less than 1 year                        Drug Abuse
# 45  6 months to less than 1 year                  Neuropathic Pain
# 46  6 months to less than 1 year                             Other
# 47  6 months to less than 1 year          Pain with Drug Tolerance
# 42  6 months to less than 1 year                        Acute Pain
# 49  6 months to less than 1 year  Stiff, Tender, & Painful Muscles
# 48  6 months to less than 1 year                       Severe Pain
# 10        1 to less than 2 years                      Chronic Pain
# 15        1 to less than 2 years                       Severe Pain
# 14        1 to less than 2 years          Pain with Drug Tolerance
# 13        1 to less than 2 years                             Other
# 12        1 to less than 2 years                  Neuropathic Pain
# 11        1 to less than 2 years                        Drug Abuse
# 16        1 to less than 2 years  Stiff, Tender, & Painful Muscles
# 8         1 to less than 2 years                        Acute Pain
# 29        2 to less than 5 years                  Neuropathic Pain
# 27        2 to less than 5 years                      Chronic Pain
# 25        2 to less than 5 years                        Acute Pain
# 33        2 to less than 5 years  Stiff, Tender, & Painful Muscles
# 28        2 to less than 5 years                        Drug Abuse
# 30        2 to less than 5 years                             Other
# 31        2 to less than 5 years          Pain with Drug Tolerance
# 32        2 to less than 5 years                       Severe Pain
# 35       5 to less than 10 years                      Chronic Pain
# 40       5 to less than 10 years                       Severe Pain
# 39       5 to less than 10 years          Pain with Drug Tolerance
# 38       5 to less than 10 years                             Other
# 37       5 to less than 10 years                  Neuropathic Pain
# 36       5 to less than 10 years                        Drug Abuse
# 41       5 to less than 10 years  Stiff, Tender, & Painful Muscles
# 34       5 to less than 10 years                        Acute Pain
# 24              10 years or more  Stiff, Tender, & Painful Muscles
# 23              10 years or more                       Severe Pain
# 22              10 years or more          Pain with Drug Tolerance
# 21              10 years or more                             Other
# 20              10 years or more                  Neuropathic Pain
# 19              10 years or more                        Drug Abuse
# 18              10 years or more                      Chronic Pain
# 17              10 years or more                        Acute Pain
#
#     total_group  total_length      prop
# 58           94          1580  0.059494
# 56           72          1580  0.045570
# 55           94          1580  0.059494
# 54          124          1580  0.078481
# 53           23          1580  0.014557
# 52          215          1580  0.136076
# 50          911          1580  0.576582
# 57           46          1580  0.029114
# 0           744          1392  0.534483
# 5            76          1392  0.054598
# 7            75          1392  0.053879
# 1           241          1392  0.173132
# 2            35          1392  0.025144
# 3           139          1392  0.099856
# 4            49          1392  0.035201
# 6            33          1392  0.023707
# 43          157           754  0.208223
# 44           33           754  0.043767
# 45           85           754  0.112732
# 46           30           754  0.039788
# 47           43           754  0.057029
# 42          361           754  0.478780
# 49           35           754  0.046419
# 48           10           754  0.013263
# 10          196           948  0.206751
# 15           26           948  0.027426
# 14           54           948  0.056962
# 13           31           948  0.032700
# 12           91           948  0.095992
# 11           43           948  0.045359
# 16           28           948  0.029536
# 8           477           948  0.503165
# 29          157          1450  0.108276
# 27          297          1450  0.204828
# 25          699          1450  0.482069
# 33           47          1450  0.032414
# 28           76          1450  0.052414
# 30           45          1450  0.031034
# 31           93          1450  0.064138
# 32           35          1450  0.024138
# 35          220           889  0.247469
# 40           26           889  0.029246
# 39           72           889  0.080990
# 38           34           889  0.038245
# 37           84           889  0.094488
# 36           39           889  0.043870
# 41           25           889  0.028121
# 34          389           889  0.437570
# 24            9           471  0.019108
# 23           20           471  0.042463
# 22           50           471  0.106157
# 21           14           471  0.029724
# 20           44           471  0.093418
# 19           29           471  0.061571
# 18          106           471  0.225053
# 17          199           471  0.422505

# %%
#interactive plot
groups = data9.group.unique()
    
trace = []
for i in range(0, len(groups)):
    trace.append(go.Bar(x = sortedLength,
                        y = data9.prop[data9.group == groups[i]],
                        name = groups[i],
                        marker = dict(color=col[groups[i]])
                        ))
    
layout = go.Layout(title = 'Proportion of Conditions Treated', 
                   yaxis = dict(title = 'Proportion'))
    
iplot(go.Figure(data = trace, layout = layout))
# Out:
# <div id="aab1c182-8ea6-48a3-82e2-7bc2a3e500f4" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             'aab1c182-8ea6-48a3-82e2-7bc2a3e500f4',
#             [{"marker": {"color": "rgb(43,140,190)"}, "name": "Stiff, Tender, & Painful Muscles", "x": ["less than 1 month", "1 to 6 months", "6 months to less than 1 year", "1 to less than 2 years", "2 to less than 5 years", "5 to less than 10 years", "10 years or more"], "y": [0.05949367088607595, 0.05387931034482758, 0.046419098143236075, 0.029535864978902954, 0.032413793103448274, 0.0281214848143982, 0.01910828025477707], "type": "bar", "uid": "34a00350-9ab2-11e8-916a-c49ded1fd344"}, {"marker": {"color": "rgb(204,235,197)"}, "name": "Pain with Drug Tolerance", "x": ["less than 1 month", "1 to 6 months", "6 months to less than 1 year", "1 to less than 2 years", "2 to less than 5 years", "5 to less than 10 years", "10 years or more"], "y": [0.04556962025316456, 0.05459770114942529, 0.05702917771883289, 0.056962025316455694, 0.06413793103448276, 0.08098987626546682, 0.10615711252653928], "type": "bar", "uid": "34a00351-9ab2-11e8-8c56-c49ded1fd344"}, {"marker": {"color": "rgb(78,179,211)"}, "name": "Other", "x": ["less than 1 month", "1 to 6 months", "6 months to less than 1 year", "1 to less than 2 years", "2 to less than 5 years", "5 to less than 10 years", "10 years or more"], "y": [0.05949367088607595, 0.035201149425287355, 0.03978779840848806, 0.03270042194092827, 0.03103448275862069, 0.03824521934758155, 0.029723991507430998], "type": "bar", "uid": "34a00352-9ab2-11e8-b3bc-c49ded1fd344"}, {"marker": {"color": "rgb(168,221,181)"}, "name": "Neuropathic Pain", "x": ["less than 1 month", "1 to 6 months", "6 months to less than 1 year", "1 to less than 2 years", "2 to less than 5 years", "5 to less than 10 years", "10 years or more"], "y": [0.07848101265822785, 0.09985632183908046, 0.11273209549071618, 0.09599156118143459, 0.10827586206896551, 0.09448818897637795, 0.09341825902335456], "type": "bar", "uid": "34a00353-9ab2-11e8-b57d-c49ded1fd344"}, {"marker": {"color": "rgb(116,196,118)"}, "name": "Drug Abuse", "x": ["less than 1 month", "1 to 6 months", "6 months to less than 1 year", "1 to less than 2 years", "2 to less than 5 years", "5 to less than 10 years", "10 years or more"], "y": [0.014556962025316455, 0.02514367816091954, 0.04376657824933687, 0.04535864978902954, 0.05241379310344828, 0.043869516310461196, 0.06157112526539278], "type": "bar", "uid": "34a00354-9ab2-11e8-a2f1-c49ded1fd344"}, {"marker": {"color": "rgb(123,204,196)"}, "name": "Chronic Pain", "x": ["less than 1 month", "1 to 6 months", "6 months to less than 1 year", "1 to less than 2 years", "2 to less than 5 years", "5 to less than 10 years", "10 years or more"], "y": [0.1360759493670886, 0.17313218390804597, 0.20822281167108753, 0.20675105485232068, 0.20482758620689656, 0.24746906636670415, 0.22505307855626328], "type": "bar", "uid": "34a00355-9ab2-11e8-8f75-c49ded1fd344"}, {"marker": {"color": "rgb(8,104,172)"}, "name": "Acute Pain", "x": ["less than 1 month", "1 to 6 months", "6 months to less than 1 year", "1 to less than 2 years", "2 to less than 5 years", "5 to less than 10 years", "10 years or more"], "y": [0.5765822784810126, 0.5344827586206896, 0.47877984084880637, 0.5031645569620253, 0.4820689655172414, 0.437570303712036, 0.42250530785562634], "type": "bar", "uid": "34a00356-9ab2-11e8-b4b6-c49ded1fd344"}, {"marker": {"color": "rgb(8,64,129)"}, "name": "Severe Pain", "x": ["less than 1 month", "1 to 6 months", "6 months to less than 1 year", "1 to less than 2 years", "2 to less than 5 years", "5 to less than 10 years", "10 years or more"], "y": [0.02911392405063291, 0.023706896551724137, 0.013262599469496022, 0.027426160337552744, 0.02413793103448276, 0.02924634420697413, 0.04246284501061571], "type": "bar", "uid": "34a00357-9ab2-11e8-bb67-c49ded1fd344"}],
#             {"title": "Proportion of Conditions Treated", "yaxis": {"title": "Proportion"}},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('aab1c182-8ea6-48a3-82e2-7bc2a3e500f4',{});}).then(function(){Plotly.animate('aab1c182-8ea6-48a3-82e2-7bc2a3e500f4');})
#         });</script>

# %% [markdown]
# ### What are the expectations?
#
# #### Average rating by drug

# %%
# group by drug and get the mean rating for each
data10 = patients.groupby(['drug']).agg({'effectiveness': 'mean', 'ease_of_use': 'mean', 'satisfaction': 'mean'}).reset_index()
data10
# Out:
#              drug  effectiveness  ease_of_use  satisfaction
# 0   Opana ER oral       3.447937     4.233792      3.304519
# 1  OxyContin oral       3.811698     4.250357      3.642653
# 2  methadone oral       4.159487     4.274977      3.856095
# 3   morphine oral       3.460581     4.234440      3.319502
# 4  oxycodone oral       3.917153     4.347849      3.737653
# 5   tramadol oral       3.282456     4.199298      3.078246

# %%
ratings = list(data10.columns.values)[1:]
ratings
# Out:
# ['effectiveness', 'ease_of_use', 'satisfaction']

# %%
#interactive plot
col = {}
col['effectiveness'] = cl.scales['6']['seq']['PuBu'][3]
col['ease_of_use'] = cl.scales['6']['seq']['PuRd'][3]
col['satisfaction'] = cl.scales['6']['seq']['YlOrBr'][3]


trace = []
for i in range(0, len(ratings)):
    trace.append(go.Bar(x = list(data10.drug),
                        y = list(data10[ratings[i]]),
                        name = ratings[i],
                        marker = dict(color=col[ratings[i]])
                        ))
    
layout = go.Layout(title = 'Average Rating by Drug', 
                   yaxis = dict(title = 'Rating'))
    
iplot(go.Figure(data = trace, layout = layout))
# Out:
# <div id="3e0831bb-6141-4a76-853d-5bd49407b402" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '3e0831bb-6141-4a76-853d-5bd49407b402',
#             [{"marker": {"color": "rgb(116,169,207)"}, "name": "effectiveness", "x": ["Opana ER oral", "OxyContin oral", "methadone oral", "morphine oral", "oxycodone oral", "tramadol oral"], "y": [3.447937131630648, 3.81169757489301, 4.15948670944088, 3.4605809128630707, 3.9171534784917683, 3.2824561403508774], "type": "bar", "uid": "34b467b6-9ab2-11e8-b748-c49ded1fd344"}, {"marker": {"color": "rgb(223,101,176)"}, "name": "ease_of_use", "x": ["Opana ER oral", "OxyContin oral", "methadone oral", "morphine oral", "oxycodone oral", "tramadol oral"], "y": [4.233791748526523, 4.250356633380885, 4.274977085242896, 4.234439834024896, 4.347849176845459, 4.1992982456140355], "type": "bar", "uid": "34b467b7-9ab2-11e8-a5ce-c49ded1fd344"}, {"marker": {"color": "rgb(254,153,41)"}, "name": "satisfaction", "x": ["Opana ER oral", "OxyContin oral", "methadone oral", "morphine oral", "oxycodone oral", "tramadol oral"], "y": [3.3045186640471513, 3.6426533523537805, 3.8560953253895507, 3.319502074688797, 3.7376526818906, 3.0782456140350876], "type": "bar", "uid": "34b467b8-9ab2-11e8-854b-c49ded1fd344"}],
#             {"title": "Average Rating by Drug", "yaxis": {"title": "Rating"}},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('3e0831bb-6141-4a76-853d-5bd49407b402',{});}).then(function(){Plotly.animate('3e0831bb-6141-4a76-853d-5bd49407b402');})
#         });</script>

# %% [markdown]
# #### Average rating by condition

# %%
# group by condition group and get the mean rating for each
data11 = patients.groupby(['group']).agg({'effectiveness': 'mean', 'ease_of_use': 'mean', 'satisfaction': 'mean'}).reset_index()
data11
# Out:
#                               group  effectiveness  ease_of_use  satisfaction
# 0                        Acute Pain       3.632367     4.276812      3.424638
# 1                        Anesthesia       3.000000     3.800000      2.600000
# 2                      Chronic Pain       3.607692     4.235256      3.435256
# 3                        Drug Abuse       4.358804     4.079734      3.760797
# 4                  Neuropathic Pain       3.705810     4.280593      3.585909
# 5                             Other       3.433628     4.056047      3.230088
# 6          Pain with Drug Tolerance       3.750480     4.335893      3.642994
# 7                       Severe Pain       3.652381     4.314286      3.390476
# 8  Stiff, Tender, & Painful Muscles       3.493976     4.250000      3.370482

# %%
# interactive plot

trace = []
for i in range(0, len(ratings)):
    trace.append(go.Bar(x = list(data11.group),
                        y = list(data11[ratings[i]]),
                        name = ratings[i],
                        marker = dict(color=col[ratings[i]])
                        ))
    
layout = go.Layout(title = 'Average Rating by Condition', 
                   yaxis = dict(title = 'Rating'))
    
iplot(go.Figure(data = trace, layout = layout))
# Out:
# <div id="58efda77-9957-402e-861a-a3d5b1b16eb1" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '58efda77-9957-402e-861a-a3d5b1b16eb1',
#             [{"marker": {"color": "rgb(116,169,207)"}, "name": "effectiveness", "x": ["Acute Pain", "Anesthesia", "Chronic Pain", "Drug Abuse", "Neuropathic Pain", "Other", "Pain with Drug Tolerance", "Severe Pain", "Stiff, Tender, & Painful Muscles"], "y": [3.632367149758454, 3.0, 3.6076923076923078, 4.358803986710964, 3.7058096415327566, 3.433628318584071, 3.7504798464491365, 3.6523809523809523, 3.4939759036144578], "type": "bar", "uid": "34c267de-9ab2-11e8-bc47-c49ded1fd344"}, {"marker": {"color": "rgb(223,101,176)"}, "name": "ease_of_use", "x": ["Acute Pain", "Anesthesia", "Chronic Pain", "Drug Abuse", "Neuropathic Pain", "Other", "Pain with Drug Tolerance", "Severe Pain", "Stiff, Tender, & Painful Muscles"], "y": [4.276811594202899, 3.8, 4.23525641025641, 4.079734219269103, 4.280593325092707, 4.056047197640118, 4.335892514395393, 4.314285714285714, 4.25], "type": "bar", "uid": "34c267df-9ab2-11e8-9574-c49ded1fd344"}, {"marker": {"color": "rgb(254,153,41)"}, "name": "satisfaction", "x": ["Acute Pain", "Anesthesia", "Chronic Pain", "Drug Abuse", "Neuropathic Pain", "Other", "Pain with Drug Tolerance", "Severe Pain", "Stiff, Tender, & Painful Muscles"], "y": [3.42463768115942, 2.6, 3.43525641025641, 3.7607973421926912, 3.585908529048208, 3.230088495575221, 3.6429942418426102, 3.3904761904761904, 3.3704819277108435], "type": "bar", "uid": "34c267e0-9ab2-11e8-8dd9-c49ded1fd344"}],
#             {"title": "Average Rating by Condition", "yaxis": {"title": "Rating"}},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('58efda77-9957-402e-861a-a3d5b1b16eb1',{});}).then(function(){Plotly.animate('58efda77-9957-402e-861a-a3d5b1b16eb1');})
#         });</script>

# %%
#HTML(cl.to_html(cl.scales['6']))
